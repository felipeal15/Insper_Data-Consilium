# %%
import pandas as pd
import os 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re

# %%
df_2022_jan = pd.read_csv("Bases/csv/2022_JAN_JUN.csv", sep=";", encoding="utf-8-sig")
df_2022_jul = pd.read_csv("Bases/csv/2022_JUL_DEZ.csv", sep=";", encoding="utf-8-sig")

df_2022 = pd.concat([df_2022_jan, df_2022_jul], ignore_index=True)
# Out:
# C:\Users\faldr\AppData\Local\Temp\ipykernel_3268\87640848.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2022_jan = pd.read_csv("Bases/csv/2022_JAN_JUN.csv", sep=";", encoding="utf-8-sig")

# %%
df_2023_jan_jun = pd.read_csv("Bases/csv/2023_JAN_JUN.csv", sep=";", encoding="utf-8-sig")
df_2023_jul_dez = pd.read_csv("Bases/csv/2023_JUL_DEZ.csv", sep=";", encoding="utf-8-sig")

df_2023 = pd.concat([df_2023_jan_jun, df_2023_jul_dez], ignore_index=True)
# Out:
# C:\Users\faldr\AppData\Local\Temp\ipykernel_3268\1568925036.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2023_jan_jun = pd.read_csv("Bases/csv/2023_JAN_JUN.csv", sep=";", encoding="utf-8-sig")

# %%
df_2024_jan_jun = pd.read_csv("Bases/csv/2024_JAN_JUN.csv", sep=";", encoding="utf-8-sig")
df_2024_jul_dez = pd.read_csv("Bases/csv/2024_JUL_DEZ.csv", sep=";", encoding="utf-8-sig")

df_2024 = pd.concat([df_2024_jan_jun, df_2024_jul_dez], ignore_index=True)
# Out:
# C:\Users\faldr\AppData\Local\Temp\ipykernel_3268\2917193620.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2024_jul_dez = pd.read_csv("Bases/csv/2024_JUL_DEZ.csv", sep=";", encoding="utf-8-sig")

# %%
df_2025_jan_jun = pd.read_csv("Bases/csv/2025_JAN_JUN.csv", sep=";", encoding="utf-8-sig")
df_2025_jul_dez = pd.read_csv("Bases/csv/2025_JUL_DEZ.csv", sep=";", encoding="utf-8-sig")

df_2025 = pd.concat([df_2025_jan_jun, df_2025_jul_dez], ignore_index=True)

# %%
df_2022.head()
# Out:
#   NOME_DEPARTAMENTO         NOME_SECCIONAL            NOME_DELEGACIA   CIDADE  \
# 0             DECAP  DEL.SEC.8º SAO MATEUS        08ª DDM SAO MATEUS  S.PAULO
# 1             DECAP  DEL.SEC.8º SAO MATEUS  54º D.P. CID. TIRADENTES  S.PAULO
# 2             DECAP       DEL.SEC.5º LESTE    29º D.P. VILA PRUDENTE  S.PAULO
# 3             DECAP      DEL.SEC.1º CENTRO               01º D.P. SE  S.PAULO
# 4             DECAP      DEL.SEC.1º CENTRO          06º D.P. CAMBUCI  S.PAULO
#
#    NUM_BO  ANO_BO DATA_COMUNICACAO_BO DATA_OCORRENCIA_BO HORA_OCORRENCIA_BO  \
# 0  AC0851  2022.0          13/01/2022         01/09/2021                NaN
# 1       4  2022.0          03/01/2022         31/12/2021           15:20:00
# 2       7  2022.0          04/01/2022         30/12/2021                NaN
# 3       8  2022.0          03/01/2022         03/01/2022           16:00:00
# 4       8  2022.0          03/01/2022         03/01/2022           13:30:00
#
#      DESCR_PERIODO  ...     LONGITUDE NOME_DELEGACIA_CIRCUNSCRIÇÃO  \
# 0  EM HORA INCERTA  ...             0                  01º D.P. SE
# 1              NaN  ...   -46,6325199                  01º D.P. SE
# 2  EM HORA INCERTA  ...  -46,63109113                  01º D.P. SE
# 3              NaN  ...   -46,6258725                  01º D.P. SE
# 4              NaN  ...  -46,63022391                  01º D.P. SE
#
#   NOME_DEPARTAMENTO_CIRCUNSCRIÇÃO NOME_SECCIONAL_CIRCUNSCRIÇÃO  \
# 0                           DECAP            DEL.SEC.1º CENTRO
# 1                           DECAP            DEL.SEC.1º CENTRO
# 2                           DECAP            DEL.SEC.1º CENTRO
# 3                           DECAP            DEL.SEC.1º CENTRO
# 4                           DECAP            DEL.SEC.1º CENTRO
#
#   NOME_MUNICIPIO_CIRCUNSCRIÇÃO             RUBRICA        DESCR_CONDUTA  \
# 0                      S.PAULO  Art. 213 - Estupro                  NaN
# 1                      S.PAULO    Furto (art. 155)  INTERIOR DE VEICULO
# 2                      S.PAULO    Furto (art. 155)           TRANSEUNTE
# 3                      S.PAULO    Furto (art. 155)  INTERIOR DE VEICULO
# 4                      S.PAULO    Furto (art. 155)  INTERIOR DE VEICULO
#
#   NATUREZA_APURADA MES_ESTATISTICA ANO_ESTATISTICA
# 0          ESTUPRO             1.0          2022.0
# 1   FURTO - OUTROS             1.0          2022.0
# 2   FURTO - OUTROS             1.0          2022.0
# 3   FURTO - OUTROS             1.0          2022.0
# 4   FURTO - OUTROS             1.0          2022.0
#
# [5 rows x 25 columns]

# %%
df_2023.head()
# Out:
#                NOME_DEPARTAMENTO        NOME_SECCIONAL        NOME_DELEGACIA  \
# 0                          DECAP     DEL.SEC.1º CENTRO        01ª DDM CENTRO
# 1                          DECAP     DEL.SEC.1º CENTRO        01ª DDM CENTRO
# 2  DIPOL - DEPTO DE INTELIGENCIA  DELEGACIA ELETRONICA  DELEGACIA ELETRONICA
# 3  DIPOL - DEPTO DE INTELIGENCIA  DELEGACIA ELETRONICA  DELEGACIA ELETRONICA
# 4  DIPOL - DEPTO DE INTELIGENCIA  DELEGACIA ELETRONICA  DELEGACIA ELETRONICA
#
#   NOME_MUNICIPIO  NUM_BO  ANO_BO DATA_REGISTRO DATA_OCORRENCIA_BO  \
# 0        S.PAULO  AP5096    2023    14/01/2023         12/01/2023
# 1        S.PAULO  BD2233    2023    25/01/2023         24/01/2023
# 2        S.PAULO  AA0063    2023    31/12/2022         30/12/2022
# 3        S.PAULO  AA0404    2023    31/12/2022         30/12/2022
# 4        S.PAULO  AA0895    2023    31/12/2022         30/12/2022
#
#   HORA_OCORRENCIA_BO DESC_PERIODO  ...      LONGITUDE  \
# 0           21:00:19          NaN  ...              0
# 1           20:40:00          NaN  ...              0
# 2                NaN      A noite  ...            NaN
# 3                NaN   Pela manhã  ...  -46,632093172
# 4                NaN      A tarde  ...  -46,626561700
#
#   NOME_DELEGACIA_CIRCUNSCRIÇÃO NOME_DEPARTAMENTO_CIRCUNSCRIÇÃO  \
# 0                  01º D.P. SE                           DECAP
# 1                  01º D.P. SE                           DECAP
# 2                  01º D.P. SE                           DECAP
# 3                  01º D.P. SE                           DECAP
# 4                  01º D.P. SE                           DECAP
#
#   NOME_SECCIONAL_CIRCUNSCRIÇÃO NOME_MUNICIPIO_CIRCUNSCRIÇÃO  \
# 0            DEL.SEC.1º CENTRO                      S.PAULO
# 1            DEL.SEC.1º CENTRO                      S.PAULO
# 2            DEL.SEC.1º CENTRO                      S.PAULO
# 3            DEL.SEC.1º CENTRO                      S.PAULO
# 4            DEL.SEC.1º CENTRO                      S.PAULO
#
#               RUBRICA DESCR_CONDUTA NATUREZA_APURADA MES_ESTATISTICA  \
# 0  Art. 213 - Estupro           NaN          ESTUPRO               1
# 1  Art. 213 - Estupro           NaN          ESTUPRO               1
# 2    Furto (art. 155)        Outros   FURTO - OUTROS               1
# 3    Furto (art. 155)        Outros   FURTO - OUTROS               1
# 4    Furto (art. 155)        Outros   FURTO - OUTROS               1
#
#   ANO_ESTATISTICA
# 0            2023
# 1            2023
# 2            2023
# 3            2023
# 4            2023
#
# [5 rows x 25 columns]

# %%
df_2024.head()
# Out:
#                NOME_DEPARTAMENTO        NOME_SECCIONAL  \
# 0                          DECAP     DEL.SEC.1º CENTRO
# 1  DIPOL - DEPTO DE INTELIGENCIA  DELEGACIA ELETRONICA
# 2                          DECAP      DEL.SEC.4º NORTE
# 3  DIPOL - DEPTO DE INTELIGENCIA  DELEGACIA ELETRONICA
# 4  DIPOL - DEPTO DE INTELIGENCIA  DELEGACIA ELETRONICA
#
#            NOME_DELEGACIA NOME_MUNICIPIO  NUM_BO  ANO_BO DATA_REGISTRO  \
# 0          01ª DDM CENTRO        S.PAULO  AB8192    2024    02/01/2024
# 1    DELEGACIA ELETRONICA        S.PAULO  AA0650    2024    01/01/2024
# 2     13º D.P. CASA VERDE        S.PAULO  AA1075    2024    01/01/2024
# 3  DELEGACIA ELETRONICA 1        S.PAULO  AA1444    2024    01/01/2024
# 4    DELEGACIA ELETRONICA        S.PAULO  AA4651    2024    01/01/2024
#
#   DATA_OCORRENCIA_BO HORA_OCORRENCIA_BO  DESC_PERIODO  ...  \
# 0         28/12/2023           23:55:00           NaN  ...
# 1         01/01/2024                NaN  De madrugada  ...
# 2         31/12/2023           23:00:00           NaN  ...
# 3         31/12/2023           23:00:00           NaN  ...
# 4         31/12/2023                NaN       A tarde  ...
#
#   NOME_MUNICIPIO_CIRCUNSCRIÇÃO                            RUBRICA  \
# 0                      S.PAULO  Estupro de vulneravel (art.217-A)
# 1                      S.PAULO                   Furto (art. 155)
# 2                      S.PAULO                   Furto (art. 155)
# 3                      S.PAULO                   Furto (art. 155)
# 4                      S.PAULO                   Furto (art. 155)
#
#          DESCR_CONDUTA       NATUREZA_APURADA MES_ESTATISTICA ANO_ESTATISTICA  \
# 0                  NaN  ESTUPRO DE VULNERÁVEL               1            2024
# 1               Outros         FURTO - OUTROS               1            2024
# 2           Transeunte         FURTO - OUTROS               1            2024
# 3  Interior de Veículo         FURTO - OUTROS               1            2024
# 4               Outros         FURTO - OUTROS               1            2024
#
#        CMD      BTL          CIA COD IBGE
# 0  CPA/M-1  7ºBPM/M  3ªCIA_4ªCIA  3550308
# 1  CPA/M-1  7ºBPM/M  3ªCIA_4ªCIA  3550308
# 2  CPA/M-1  7ºBPM/M  3ªCIA_4ªCIA  3550308
# 3  CPA/M-1  7ºBPM/M  3ªCIA_4ªCIA  3550308
# 4  CPA/M-1  7ºBPM/M  3ªCIA_4ªCIA  3550308
#
# [5 rows x 29 columns]

# %%
df_2025.head()
# Out:
#                NOME_DEPARTAMENTO          NOME_SECCIONAL  \
# 0                          DECAP       DEL.SEC.1º CENTRO
# 1                          DECAP       DEL.SEC.1º CENTRO
# 2                          DECAP       DEL.SEC.1º CENTRO
# 3                          DECAP  DEL.SEC.6º SANTO AMARO
# 4  DIPOL - DEPTO DE INTELIGENCIA    DELEGACIA ELETRONICA
#
#            NOME_DELEGACIA NOME_MUNICIPIO  NUM_BO  ANO_BO DATA_REGISTRO  \
# 0          01ª DDM CENTRO        S.PAULO  AA2328    2025    01/01/2025
# 1          01ª DDM CENTRO        S.PAULO  AM7136    2025    10/01/2025
# 2          01ª DDM CENTRO        S.PAULO  AQ9561    2025    14/01/2025
# 3     06ª DDM SANTO AMARO        S.PAULO  BH3385    2025    27/01/2025
# 4  DELEGACIA ELETRONICA 1        S.PAULO  AA1448    2025    01/01/2025
#
#   DATA_OCORRENCIA_BO HORA_OCORRENCIA_BO     DESC_PERIODO  ...  \
# 0         31/12/2024           18:00:00              NaN  ...
# 1         10/01/2025           00:00:00              NaN  ...
# 2         14/01/2025                NaN  Em hora incerta  ...
# 3         25/01/2025           18:00:14              NaN  ...
# 4         31/12/2024           10:30:00              NaN  ...
#
#   NOME_SECCIONAL_CIRCUNSCRICAO NOME_MUNICIPIO_CIRCUNSCRICAO  \
# 0            DEL.SEC.1º CENTRO                      S.PAULO
# 1            DEL.SEC.1º CENTRO                      S.PAULO
# 2            DEL.SEC.1º CENTRO                      S.PAULO
# 3            DEL.SEC.1º CENTRO                      S.PAULO
# 4            DEL.SEC.1º CENTRO                      S.PAULO
#
#                              RUBRICA DESCR_CONDUTA       NATUREZA_APURADA  \
# 0  Estupro de vulneravel (art.217-A)           NaN  ESTUPRO DE VULNERÁVEL
# 1  Estupro de vulneravel (art.217-A)           NaN  ESTUPRO DE VULNERÁVEL
# 2  Estupro de vulneravel (art.217-A)           NaN  ESTUPRO DE VULNERÁVEL
# 3  Estupro de vulneravel (art.217-A)           NaN  ESTUPRO DE VULNERÁVEL
# 4                   Furto (art. 155)        Outros         FURTO - OUTROS
#
#   MES_ESTATISTICA ANO_ESTATISTICA     CMD      BTL          CIA
# 0               1            2025  CPA/M1  7ºBPM/M  3ªCIA 4ªCIA
# 1               1            2025  CPA/M1  7ºBPM/M  3ªCIA 4ªCIA
# 2               1            2025  CPA/M1  7ºBPM/M  3ªCIA 4ªCIA
# 3               1            2025  CPA/M1  7ºBPM/M  3ªCIA 4ªCIA
# 4               1            2025  CPA/M1  7ºBPM/M  3ªCIA 4ªCIA
#
# [5 rows x 29 columns]

# %%
df_total = pd.concat([df_2022, df_2023, df_2024, df_2025], ignore_index=True)

# %%
df_total["ANO_ESTATISTICA"].value_counts()
# Out:
# ANO_ESTATISTICA
# 2023.0    1241911
# 2022.0    1197973
# 2024.0    1191814
# 2025.0    1161132
# Name: count, dtype: int64

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df_total.head()
# Out:
#   NOME_DEPARTAMENTO         NOME_SECCIONAL            NOME_DELEGACIA   CIDADE  \
# 0             DECAP  DEL.SEC.8º SAO MATEUS        08ª DDM SAO MATEUS  S.PAULO
# 1             DECAP  DEL.SEC.8º SAO MATEUS  54º D.P. CID. TIRADENTES  S.PAULO
# 2             DECAP       DEL.SEC.5º LESTE    29º D.P. VILA PRUDENTE  S.PAULO
# 3             DECAP      DEL.SEC.1º CENTRO               01º D.P. SE  S.PAULO
# 4             DECAP      DEL.SEC.1º CENTRO          06º D.P. CAMBUCI  S.PAULO
#
#    NUM_BO  ANO_BO DATA_COMUNICACAO_BO DATA_OCORRENCIA_BO HORA_OCORRENCIA_BO  \
# 0  AC0851  2022.0          13/01/2022         01/09/2021                NaN
# 1       4  2022.0          03/01/2022         31/12/2021           15:20:00
# 2       7  2022.0          04/01/2022         30/12/2021                NaN
# 3       8  2022.0          03/01/2022         03/01/2022           16:00:00
# 4       8  2022.0          03/01/2022         03/01/2022           13:30:00
#
#      DESCR_PERIODO  ... DESC_PERIODO DESCR_SUBTIPOLOCAL  CMD  BTL  CIA  \
# 0  EM HORA INCERTA  ...          NaN                NaN  NaN  NaN  NaN
# 1              NaN  ...          NaN                NaN  NaN  NaN  NaN
# 2  EM HORA INCERTA  ...          NaN                NaN  NaN  NaN  NaN
# 3              NaN  ...          NaN                NaN  NaN  NaN  NaN
# 4              NaN  ...          NaN                NaN  NaN  NaN  NaN
#
#   COD IBGE NOME_DELEGACIA_CIRCUNSCRICAO NOME_DEPARTAMENTO_CIRCUNSCRICAO  \
# 0      NaN                          NaN                             NaN
# 1      NaN                          NaN                             NaN
# 2      NaN                          NaN                             NaN
# 3      NaN                          NaN                             NaN
# 4      NaN                          NaN                             NaN
#
#   NOME_SECCIONAL_CIRCUNSCRICAO NOME_MUNICIPIO_CIRCUNSCRICAO
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
# [5 rows x 37 columns]

# %%
# Análise de Colunas: Comparação entre os anos
print("=" * 80)
print("COLUNAS POR ANO")
print("=" * 80)

years_data = {
    "2022": df_2022,
    "2023": df_2023,
    "2024": df_2024,
    "2025": df_2025
}

for year, df in years_data.items():
    print(f"\n{year}: {df.shape[0]} linhas, {df.shape[1]} colunas")
    print(f"Colunas: {sorted(df.columns.tolist())}")

#Pegando essencialmente todas as colunas, e vendo como elas diferem ao longo dos anos
# Out:
# ================================================================================
# COLUNAS POR ANO
# ================================================================================
#
# 2022: 1198114 linhas, 25 colunas
# Colunas: ['ANO_BO', 'ANO_ESTATISTICA', 'BAIRRO', 'CIDADE', 'DATA_COMUNICACAO_BO', 'DATA_OCORRENCIA_BO', 'DESCR_CONDUTA', 'DESCR_PERIODO', 'DESCR_TIPOLOCAL', 'HORA_OCORRENCIA_BO', 'LATITUDE', 'LOGRADOURO', 'LONGITUDE', 'MES_ESTATISTICA', 'NATUREZA_APURADA', 'NOME_DELEGACIA', 'NOME_DELEGACIA_CIRCUNSCRIÇÃO', 'NOME_DEPARTAMENTO', 'NOME_DEPARTAMENTO_CIRCUNSCRIÇÃO', 'NOME_MUNICIPIO_CIRCUNSCRIÇÃO', 'NOME_SECCIONAL', 'NOME_SECCIONAL_CIRCUNSCRIÇÃO', 'NUMERO_LOGRADOURO', 'NUM_BO', 'RUBRICA']
#
# 2023: 1241911 linhas, 25 colunas
# Colunas: ['ANO_BO', 'ANO_ESTATISTICA', 'BAIRRO', 'DATA_OCORRENCIA_BO', 'DATA_REGISTRO', 'DESCR_CONDUTA', 'DESCR_SUBTIPOLOCAL', 'DESC_PERIODO', 'HORA_OCORRENCIA_BO', 'LATITUDE', 'LOGRADOURO', 'LONGITUDE', 'MES_ESTATISTICA', 'NATUREZA_APURADA', 'NOME_DELEGACIA', 'NOME_DELEGACIA_CIRCUNSCRIÇÃO', 'NOME_DEPARTAMENTO', 'NOME_DEPARTAMENTO_CIRCUNSCRIÇÃO', 'NOME_MUNICIPIO', 'NOME_MUNICIPIO_CIRCUNSCRIÇÃO', 'NOME_SECCIONAL', 'NOME_SECCIONAL_CIRCUNSCRIÇÃO', 'NUMERO_LOGRADOURO', 'NUM_BO', 'RUBRICA']
#
# 2024: 1191814 linhas, 29 colunas
# Colunas: ['ANO_BO', 'ANO_ESTATISTICA', 'BAIRRO', 'BTL', 'CIA', 'CMD', 'COD IBGE', 'DATA_OCORRENCIA_BO', 'DATA_REGISTRO', 'DESCR_CONDUTA', 'DESCR_SUBTIPOLOCAL', 'DESC_PERIODO', 'HORA_OCORRENCIA_BO', 'LATITUDE', 'LOGRADOURO', 'LONGITUDE', 'MES_ESTATISTICA', 'NATUREZA_APURADA', 'NOME_DELEGACIA', 'NOME_DELEGACIA_CIRCUNSCRIÇÃO', 'NOME_DEPARTAMENTO', 'NOME_DEPARTAMENTO_CIRCUNSCRIÇÃO', 'NOME_MUNICIPIO', 'NOME_MUNICIPIO_CIRCUNSCRIÇÃO', 'NOME_SECCIONAL', 'NOME_SECCIONAL_CIRCUNSCRIÇÃO', 'NUMERO_LOGRADOURO', 'NUM_BO', 'RUBRICA']
#
# 2025: 1161132 linhas, 29 colunas
# Colunas: ['ANO_BO', 'ANO_ESTATISTICA', 'BAIRRO', 'BTL', 'CIA', 'CMD', 'DATA_OCORRENCIA_BO', 'DATA_REGISTRO', 'DESCR_CONDUTA', 'DESCR_SUBTIPOLOCAL', 'DESCR_TIPOLOCAL', 'DESC_PERIODO', 'HORA_OCORRENCIA_BO', 'LATITUDE', 'LOGRADOURO', 'LONGITUDE', 'MES_ESTATISTICA', 'NATUREZA_APURADA', 'NOME_DELEGACIA', 'NOME_DELEGACIA_CIRCUNSCRICAO', 'NOME_DEPARTAMENTO', 'NOME_DEPARTAMENTO_CIRCUNSCRICAO', 'NOME_MUNICIPIO', 'NOME_MUNICIPIO_CIRCUNSCRICAO', 'NOME_SECCIONAL', 'NOME_SECCIONAL_CIRCUNSCRICAO', 'NUMERO_LOGRADOURO', 'NUM_BO', 'RUBRICA']

# %% [markdown]
# Bem perceptível que os asno 2024 e 2025 tem as mesmas colunas, porem ainda assim com os nomes nao padronizados, enquanto os anos 2023 e 2022 tem essa semelhanca entre si
#
# (Apesar de que na verdade tem algumas informacoes que uma ou outra nao tem)

# %%
# Encontrar colunas comuns e diferences
print("\n" + "=" * 80)
print("ANÁLISE DE DIFERENÇAS NAS COLUNAS")
print("=" * 80)

all_columns = {year: set(df.columns) for year, df in years_data.items()}

# Colunas comuns em todos os anos
common_columns = set.intersection(*all_columns.values())
print(f"\n Colunas presentes em TODOS os anos ({len(common_columns)} colunas):")
print(sorted(common_columns))

# Colunas por ano que podem estar faltando em outras
print("\n\n" + "-" * 80)
print("COLUNAS ESPECÍFICAS POR ANO (não presentes em todos):")
print("-" * 80)

for year in ["2022", "2023", "2024", "2025"]:
    unique_to_year = all_columns[year] - common_columns
    if unique_to_year:
        print(f"\n{year}: {unique_to_year}")
    else:
        print(f"\n{year}: Nenhuma coluna única")

# Colunas faltando por ano
print("\n\n" + "-" * 80)
print("COLUNAS FALTANDO EM CADA ANO:")
print("-" * 80)

for year in ["2022", "2023", "2024", "2025"]:
    missing = set()
    for other_year in ["2022", "2023", "2024", "2025"]:
        if year != other_year:
            missing.update(all_columns[other_year] - all_columns[year])
    
    if missing:
        print(f"\n{year} (faltam {len(missing)} colunas):")
        for col in sorted(missing):
            print(f"  - {col}")
# Out:
# ================================================================================
# ANÁLISE DE DIFERENÇAS NAS COLUNAS
# ================================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2 print("\n" + "=" * 80)
#       3 print("ANÁLISE DE DIFERENÇAS NAS COLUNAS")
#       4 print("=" * 80)
#       5
# ----> 6 all_columns = {year: set(df.columns) for year, df in years_data.items()}
#       7
#       8 # Colunas comuns em todos os anos
#       9 common_columns = set.intersection(*all_columns.values())
#
# NameError: name 'years_data' is not defined

# %%
# Mapeamento de Colunas Equivalentes (mesma função, nomes diferentes)
print("\n" + "=" * 80)
print("MAPEAMENTO DE COLUNAS COM MESMA FUNÇÃO (nomes diferentes)")
print("=" * 80)

column_mapping = {
    "PERÍODO": ["DESCR_PERIODO", "DESC_PERIODO"],
    "TIPO LOCAL": ["DESCR_TIPOLOCAL", "DESCR_SUBTIPOLOCAL"],
    "MUNICÍPIO": ["CIDADE", "NOME_MUNICIPIO"],
    "CIRCUNSCRIÇÃO (acentuação)": ["NOME_DELEGACIA_CIRCUNSCRIÇÃO", "NOME_DELEGACIA_CIRCUNSCRICAO"],
}

for func, variants in column_mapping.items():
    print(f"\n{func}:")
    for col in variants:
        years_with_col = [year for year, cols in all_columns.items() if col in cols]
        print(f"  {col:40} → {', '.join(years_with_col)}")

# Colunas novass (2024+)
print("\n" + "=" * 80)
print("COLUNAS NOVAS EM 2024-2025 (não em 2022-2023):")
print("=" * 80)
new_cols_2024 = all_columns["2024"] - (all_columns["2022"] | all_columns["2023"])
print(f"\nNovas em 2024: {new_cols_2024}")

# Comparar 2024 vs 2025
print("\n" + "-" * 80)
print("Diferença entre 2024 e 2025:")
print("-" * 80)
only_2024 = all_columns["2024"] - all_columns["2025"]
only_2025 = all_columns["2025"] - all_columns["2024"]
print(f"Apenas em 2024: {only_2024}")
print(f"Apenas em 2025: {only_2025}")
# Out:
# ================================================================================
# MAPEAMENTO DE COLUNAS COM MESMA FUNÇÃO (nomes diferentes)
# ================================================================================
#
# PERÍODO:
#   DESCR_PERIODO                            → 2022
#   DESC_PERIODO                             → 2023, 2024, 2025
#
# TIPO LOCAL:
#   DESCR_TIPOLOCAL                          → 2022, 2025
#   DESCR_SUBTIPOLOCAL                       → 2023, 2024, 2025
#
# MUNICÍPIO:
#   CIDADE                                   → 2022
#   NOME_MUNICIPIO                           → 2023, 2024, 2025
#
# CIRCUNSCRIÇÃO (acentuação):
#   NOME_DELEGACIA_CIRCUNSCRIÇÃO             → 2022, 2023, 2024
#   NOME_DELEGACIA_CIRCUNSCRICAO             → 2025
#
# ================================================================================
# COLUNAS NOVAS EM 2024-2025 (não em 2022-2023):
# ================================================================================
#
# Novas em 2024: {'BTL', 'CMD', 'COD IBGE', 'CIA'}
#
# --------------------------------------------------------------------------------
# Diferença entre 2024 e 2025:
# --------------------------------------------------------------------------------
# Apenas em 2024: {'NOME_SECCIONAL_CIRCUNSCRIÇÃO', 'NOME_DELEGACIA_CIRCUNSCRIÇÃO', 'NOME_MUNICIPIO_CIRCUNSCRIÇÃO', 'NOME_DEPARTAMENTO_CIRCUNSCRIÇÃO', 'COD IBGE'}
# Apenas em 2025: {'NOME_MUNICIPIO_CIRCUNSCRICAO', 'NOME_DEPARTAMENTO_CIRCUNSCRICAO', 'DESCR_TIPOLOCAL', 'NOME_DELEGACIA_CIRCUNSCRICAO', 'NOME_SECCIONAL_CIRCUNSCRICAO'}

# %%
# SOLUÇÃO: Padronizar nomes de colunas e filtrar apenas colunas completas

# 1. Definir mapeamento completo de renomeação
rename_mapping = {
    # Período
    "DESCR_PERIODO": "DESC_PERIODO",
    
    # Tipo de Local (2025 trouxe de volta DESCR_TIPOLOCAL)
    # Vamos manter DESCR_SUBTIPOLOCAL como padrão
    
    # Município
    "CIDADE": "NOME_MUNICIPIO",
    
    # Acentuação (remover circunflexo para padronizar)
    "NOME_DELEGACIA_CIRCUNSCRIÇÃO": "NOME_DELEGACIA_CIRCUNSCRICAO",
    "NOME_DEPARTAMENTO_CIRCUNSCRIÇÃO": "NOME_DEPARTAMENTO_CIRCUNSCRICAO",
    "NOME_MUNICIPIO_CIRCUNSCRIÇÃO": "NOME_MUNICIPIO_CIRCUNSCRICAO",
    "NOME_SECCIONAL_CIRCUNSCRIÇÃO": "NOME_SECCIONAL_CIRCUNSCRICAO",
}

# 2. Aplicar renomeação em cada dataframe
for year in ["2022", "2023", "2024", "2025"]:
    years_data[year] = years_data[year].rename(columns=rename_mapping)

# 3. Recriar df_total com colunas renomeadas
df_total = pd.concat([years_data[year] for year in ["2022", "2023", "2024", "2025"]], ignore_index=True)

print("=" * 80)
print("COLUNAS APÓS PADRONIZAÇÃO")
print("=" * 80)

for year in ["2022", "2023", "2024", "2025"]:
    print(f"\n{year}: {len(years_data[year].columns)} colunas")
    print(f"Colunas: {sorted(years_data[year].columns.tolist())}")
# Out:
# ================================================================================
# COLUNAS APÓS PADRONIZAÇÃO
# ================================================================================
#
# 2022: 25 colunas
# Colunas: ['ANO_BO', 'ANO_ESTATISTICA', 'BAIRRO', 'DATA_COMUNICACAO_BO', 'DATA_OCORRENCIA_BO', 'DESCR_CONDUTA', 'DESCR_TIPOLOCAL', 'DESC_PERIODO', 'HORA_OCORRENCIA_BO', 'LATITUDE', 'LOGRADOURO', 'LONGITUDE', 'MES_ESTATISTICA', 'NATUREZA_APURADA', 'NOME_DELEGACIA', 'NOME_DELEGACIA_CIRCUNSCRICAO', 'NOME_DEPARTAMENTO', 'NOME_DEPARTAMENTO_CIRCUNSCRICAO', 'NOME_MUNICIPIO', 'NOME_MUNICIPIO_CIRCUNSCRICAO', 'NOME_SECCIONAL', 'NOME_SECCIONAL_CIRCUNSCRICAO', 'NUMERO_LOGRADOURO', 'NUM_BO', 'RUBRICA']
#
# 2023: 25 colunas
# Colunas: ['ANO_BO', 'ANO_ESTATISTICA', 'BAIRRO', 'DATA_OCORRENCIA_BO', 'DATA_REGISTRO', 'DESCR_CONDUTA', 'DESCR_SUBTIPOLOCAL', 'DESC_PERIODO', 'HORA_OCORRENCIA_BO', 'LATITUDE', 'LOGRADOURO', 'LONGITUDE', 'MES_ESTATISTICA', 'NATUREZA_APURADA', 'NOME_DELEGACIA', 'NOME_DELEGACIA_CIRCUNSCRICAO', 'NOME_DEPARTAMENTO', 'NOME_DEPARTAMENTO_CIRCUNSCRICAO', 'NOME_MUNICIPIO', 'NOME_MUNICIPIO_CIRCUNSCRICAO', 'NOME_SECCIONAL', 'NOME_SECCIONAL_CIRCUNSCRICAO', 'NUMERO_LOGRADOURO', 'NUM_BO', 'RUBRICA']
#
# 2024: 29 colunas
# Colunas: ['ANO_BO', 'ANO_ESTATISTICA', 'BAIRRO', 'BTL', 'CIA', 'CMD', 'COD IBGE', 'DATA_OCORRENCIA_BO', 'DATA_REGISTRO', 'DESCR_CONDUTA', 'DESCR_SUBTIPOLOCAL', 'DESC_PERIODO', 'HORA_OCORRENCIA_BO', 'LATITUDE', 'LOGRADOURO', 'LONGITUDE', 'MES_ESTATISTICA', 'NATUREZA_APURADA', 'NOME_DELEGACIA', 'NOME_DELEGACIA_CIRCUNSCRICAO', 'NOME_DEPARTAMENTO', 'NOME_DEPARTAMENTO_CIRCUNSCRICAO', 'NOME_MUNICIPIO', 'NOME_MUNICIPIO_CIRCUNSCRICAO', 'NOME_SECCIONAL', 'NOME_SECCIONAL_CIRCUNSCRICAO', 'NUMERO_LOGRADOURO', 'NUM_BO', 'RUBRICA']
#
# 2025: 29 colunas
# Colunas: ['ANO_BO', 'ANO_ESTATISTICA', 'BAIRRO', 'BTL', 'CIA', 'CMD', 'DATA_OCORRENCIA_BO', 'DATA_REGISTRO', 'DESCR_CONDUTA', 'DESCR_SUBTIPOLOCAL', 'DESCR_TIPOLOCAL', 'DESC_PERIODO', 'HORA_OCORRENCIA_BO', 'LATITUDE', 'LOGRADOURO', 'LONGITUDE', 'MES_ESTATISTICA', 'NATUREZA_APURADA', 'NOME_DELEGACIA', 'NOME_DELEGACIA_CIRCUNSCRICAO', 'NOME_DEPARTAMENTO', 'NOME_DEPARTAMENTO_CIRCUNSCRICAO', 'NOME_MUNICIPIO', 'NOME_MUNICIPIO_CIRCUNSCRICAO', 'NOME_SECCIONAL', 'NOME_SECCIONAL_CIRCUNSCRICAO', 'NUMERO_LOGRADOURO', 'NUM_BO', 'RUBRICA']

# %%
# Identificar colunas COMPLETAS (presentes em todos os 4 anos)
print("\n" + "=" * 80)
print("ANÁLISE FINAL: COLUNAS COMPLETAS vs INCOMPLETAS")
print("=" * 80)

# Atualizar sets de colunas
all_columns_after = {year: set(years_data[year].columns) for year in ["2022", "2023", "2024", "2025"]}

# Colunas comuns em todos
complete_columns = set.intersection(*all_columns_after.values())
print(f"\n✓ COLUNAS COMPLETAS (presentes em todos 4 anos): {len(complete_columns)}")
print(sorted(complete_columns))

# Colunas incompletas
incomplete_columns = set.union(*all_columns_after.values()) - complete_columns
print(f"\n✗ COLUNAS INCOMPLETAS (faltam em algum ano): {len(incomplete_columns)}")

for col in sorted(incomplete_columns):
    years_present = [year for year in ["2022", "2023", "2024", "2025"] if col in all_columns_after[year]]
    years_missing = [year for year in ["2022", "2023", "2024", "2025"] if col not in all_columns_after[year]]
    print(f"  {col:45} → Tem: {years_present}, Falta em: {years_missing}")

# Criar df_total_completo com apenas colunas completas
df_total_completo = df_total[sorted(complete_columns)]

print("\n" + "=" * 80)
print("RESULTADO FINAL")
print("=" * 80)
print(f"\ndf_total (com todas as colunas):")
print(f"  - Linhas: {df_total.shape[0]}")
print(f"  - Colunas: {df_total.shape[1]}")

print(f"\ndf_total_completo (apenas colunas presentes em todos os anos):")
print(f"  - Linhas: {df_total_completo.shape[0]}")
print(f"  - Colunas: {df_total_completo.shape[1]}")
print(f"  - Colunas: {sorted(df_total_completo.columns.tolist())}")
# Out:
# ================================================================================
# ANÁLISE FINAL: COLUNAS COMPLETAS vs INCOMPLETAS
# ================================================================================
#
# ✓ COLUNAS COMPLETAS (presentes em todos 4 anos): 23
# ['ANO_BO', 'ANO_ESTATISTICA', 'BAIRRO', 'DATA_OCORRENCIA_BO', 'DESCR_CONDUTA', 'DESC_PERIODO', 'HORA_OCORRENCIA_BO', 'LATITUDE', 'LOGRADOURO', 'LONGITUDE', 'MES_ESTATISTICA', 'NATUREZA_APURADA', 'NOME_DELEGACIA', 'NOME_DELEGACIA_CIRCUNSCRICAO', 'NOME_DEPARTAMENTO', 'NOME_DEPARTAMENTO_CIRCUNSCRICAO', 'NOME_MUNICIPIO', 'NOME_MUNICIPIO_CIRCUNSCRICAO', 'NOME_SECCIONAL', 'NOME_SECCIONAL_CIRCUNSCRICAO', 'NUMERO_LOGRADOURO', 'NUM_BO', 'RUBRICA']
#
# ✗ COLUNAS INCOMPLETAS (faltam em algum ano): 8
#   BTL                                           → Tem: ['2024', '2025'], Falta em: ['2022', '2023']
#   CIA                                           → Tem: ['2024', '2025'], Falta em: ['2022', '2023']
#   CMD                                           → Tem: ['2024', '2025'], Falta em: ['2022', '2023']
#   COD IBGE                                      → Tem: ['2024'], Falta em: ['2022', '2023', '2025']
#   DATA_COMUNICACAO_BO                           → Tem: ['2022'], Falta em: ['2023', '2024', '2025']
#   DATA_REGISTRO                                 → Tem: ['2023', '2024', '2025'], Falta em: ['2022']
#   DESCR_SUBTIPOLOCAL                            → Tem: ['2023', '2024', '2025'], Falta em: ['2022']
#   DESCR_TIPOLOCAL                               → Tem: ['2022', '2025'], Falta em: ['2023', '2024']
#
# ================================================================================
# RESULTADO FINAL
# ================================================================================
#
# df_total (com todas as colunas):
#   - Linhas: 4792971
#   - Colunas: 31
#
# df_total_completo (apenas colunas presentes em todos os anos):
#   - Linhas: 4792971
#   - Colunas: 23
#   - Colunas: ['ANO_BO', 'ANO_ESTATISTICA', 'BAIRRO', 'DATA_OCORRENCIA_BO', 'DESCR_CONDUTA', 'DESC_PERIODO', 'HORA_OCORRENCIA_BO', 'LATITUDE', 'LOGRADOURO', 'LONGITUDE', 'MES_ESTATISTICA', 'NATUREZA_APURADA', 'NOME_DELEGACIA', 'NOME_DELEGACIA_CIRCUNSCRICAO', 'NOME_DEPARTAMENTO', 'NOME_DEPARTAMENTO_CIRCUNSCRICAO', 'NOME_MUNICIPIO', 'NOME_MUNICIPIO_CIRCUNSCRICAO', 'NOME_SECCIONAL', 'NOME_SECCIONAL_CIRCUNSCRICAO', 'NUMERO_LOGRADOURO', 'NUM_BO', 'RUBRICA']

# %%
# Resumo Executivo - Salvar em arquivo
resumo = """
RESUMO EXECUTIVO: PADRONIZAÇÃO DE COLUNAS
==========================================

1. MAPEAMENTO DE COLUNAS EQUIVALENTES (mesma função, nomes diferentes):
   
   ✓ DESCR_PERIODO → DESC_PERIODO
     2022: DESCR_PERIODO
     2023-2025: DESC_PERIODO
   
   ✓ CIDADE → NOME_MUNICIPIO
     2022: CIDADE
     2023-2025: NOME_MUNICIPIO
   
   ✓ Acentuação padronizada (SEM circunflexo)
     2022-2024: NOME_*_CIRCUNSCRIÇÃO
     2025: NOME_*_CIRCUNSCRICAO
     → Padronizado para: NOME_*_CIRCUNSCRICAO

2. COLUNAS NOVAS (2024-2025):
   - BTL, CIA, CMD, COD IBGE
   
3. COLUNAS FALTANDO:
   - 2022 não tem: DATA_REGISTRO, DESCR_SUBTIPOLOCAL
   - 2023 não tem: DATA_COMUNICACAO_BO, DESCR_TIPOLOCAL
   - 2024 não tem: DESCR_TIPOLOCAL
   - 2025 não tem: COD IBGE

4. RESULTADO FINAL:
   df_total_completo = Dataset com APENAS as colunas presentes em TODOS os 4 anos
   
   Colunas completas:
"""

# Adicionar colunas completas ao resumo
for col in sorted(complete_columns):
    resumo += f"\n   - {col}"

print(resumo)
# Out:
# RESUMO EXECUTIVO: PADRONIZAÇÃO DE COLUNAS
# ==========================================
#
# 1. MAPEAMENTO DE COLUNAS EQUIVALENTES (mesma função, nomes diferentes):
#
#    ✓ DESCR_PERIODO → DESC_PERIODO
#      2022: DESCR_PERIODO
#      2023-2025: DESC_PERIODO
#
#    ✓ CIDADE → NOME_MUNICIPIO
#      2022: CIDADE
#      2023-2025: NOME_MUNICIPIO
#
#    ✓ Acentuação padronizada (SEM circunflexo)
#      2022-2024: NOME_*_CIRCUNSCRIÇÃO
#      2025: NOME_*_CIRCUNSCRICAO
#      → Padronizado para: NOME_*_CIRCUNSCRICAO
#
# 2. COLUNAS NOVAS (2024-2025):
#    - BTL, CIA, CMD, COD IBGE
#
# 3. COLUNAS FALTANDO:
#    - 2022 não tem: DATA_REGISTRO, DESCR_SUBTIPOLOCAL
#    - 2023 não tem: DATA_COMUNICACAO_BO, DESCR_TIPOLOCAL
#    - 2024 não tem: DESCR_TIPOLOCAL
#    - 2025 não tem: COD IBGE
#
# 4. RESULTADO FINAL:
#    df_total_completo = Dataset com APENAS as colunas presentes em TODOS os 4 anos
#
#    Colunas completas:
#
#    - ANO_BO
#    - ANO_ESTATISTICA
#    - BAIRRO
#    - DATA_OCORRENCIA_BO
#    - DESCR_CONDUTA
#    - DESC_PERIODO
#    - HORA_OCORRENCIA_BO
#    - LATITUDE
#    - LOGRADOURO
#    - LONGITUDE
#    - MES_ESTATISTICA
#    - NATUREZA_APURADA
#    - NOME_DELEGACIA
#    - NOME_DELEGACIA_CIRCUNSCRICAO
#    - NOME_DEPARTAMENTO
#    - NOME_DEPARTAMENTO_CIRCUNSCRICAO
#    - NOME_MUNICIPIO
#    - NOME_MUNICIPIO_CIRCUNSCRICAO
#    - NOME_SECCIONAL
#    - NOME_SECCIONAL_CIRCUNSCRICAO
#    - NUMERO_LOGRADOURO
#    - NUM_BO
#    - RUBRICA

# %%
# Comparação antes/depois e duas opções de dataset final
print("\n" + "=" * 80)
print("TWO OPTIONS FOR YOUR FINAL DATASET")
print("=" * 80)

print(f"\n📊 OPTION 1: df_total (with standardized column names)")
print(f"   Colunas: {df_total.shape[1]}")
print(f"   Linhas: {df_total.shape[0]:,}")
print(f"   ⚠️  Contém valores NaN onde colunas faltam:")
for col in sorted(incomplete_columns):
    null_count = df_total[col].isna().sum() if col in df_total.columns else 0
    print(f"      - {col:40} → {null_count:,} NaN values")

print(f"\n📊 OPTION 2: df_total_completo (only complete columns)")
print(f"   Colunas: {df_total_completo.shape[1]}")
print(f"   Linhas: {df_total_completo.shape[0]:,}")
print(f"   ✓ SEM valores NaN (dados 100% completos)")
print(f"   ✓ {len(complete_columns)} colunas consistentes em todos os anos")

print("\n" + "-" * 80)
print("RECOMENDAÇÃO:")
print("-" * 80)
print("Use 'df_total_completo' para análises mais limpas e consistentes!")
print("Todas as colunas têm dados em todos os 4 anos de períodos.")

# Preview dos dados
print("\n" + "=" * 80)
print("PREVIEW: df_total_completo.head()")
print("=" * 80)
print(df_total_completo.head())
# Out:
# ================================================================================
# TWO OPTIONS FOR YOUR FINAL DATASET
# ================================================================================
#
# 📊 OPTION 1: df_total (with standardized column names)
#    Colunas: 31
#    Linhas: 4,792,971
#    ⚠️  Contém valores NaN onde colunas faltam:
#       - BTL                                      → 2,440,025 NaN values
#       - CIA                                      → 2,440,025 NaN values
#       - CMD                                      → 2,440,025 NaN values
#       - COD IBGE                                 → 3,601,157 NaN values
#       - DATA_COMUNICACAO_BO                      → 3,598,179 NaN values
#       - DATA_REGISTRO                            → 1,198,115 NaN values
#       - DESCR_SUBTIPOLOCAL                       → 1,218,841 NaN values
#       - DESCR_TIPOLOCAL                          → 2,434,547 NaN values
#
# 📊 OPTION 2: df_total_completo (only complete columns)
#    Colunas: 23
#    Linhas: 4,792,971
#    ✓ SEM valores NaN (dados 100% completos)
#    ✓ 23 colunas consistentes em todos os anos
#
# --------------------------------------------------------------------------------
# RECOMENDAÇÃO:
# --------------------------------------------------------------------------------
# Use 'df_total_completo' para análises mais limpas e consistentes!
# Todas as colunas têm dados em todos os 4 anos de períodos.
#
# ================================================================================
# PREVIEW: df_total_completo.head()
# ================================================================================
#    ANO_BO  ANO_ESTATISTICA                         BAIRRO DATA_OCORRENCIA_BO  \
# 0  2022.0           2022.0                             SE         01/09/2021
# 1  2022.0           2022.0  Centro Histórico de São Paulo         31/12/2021
# 2  2022.0           2022.0                             SE         30/12/2021
# 3  2022.0           2022.0                      Liberdade         03/01/2022
# 4  2022.0           2022.0                      LIBERDADE         03/01/2022
#
#          DESCR_CONDUTA     DESC_PERIODO HORA_OCORRENCIA_BO      LATITUDE  \
# 0                  NaN  EM HORA INCERTA                NaN             0
# 1  INTERIOR DE VEICULO              NaN           15:20:00   -23,5436238
# 2           TRANSEUNTE  EM HORA INCERTA                NaN  -23,54502538
# 3  INTERIOR DE VEICULO              NaN           16:00:00   -23,5535658
# 4  INTERIOR DE VEICULO              NaN           13:30:00  -23,55805038
#
#                                   LOGRADOURO     LONGITUDE  ...  \
# 0  VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS             0  ...
# 1                                25 de Março   -46,6325199  ...
# 2                        PARQUE DOM PEDRO II  -46,63109113  ...
# 3                 Viaduto Therezinha Zerbini   -46,6258725  ...
# 4                            RUA DO GLICERIO  -46,63022391  ...
#
#    NOME_DELEGACIA_CIRCUNSCRICAO NOME_DEPARTAMENTO  \
# 0                   01º D.P. SE             DECAP
# 1                   01º D.P. SE             DECAP
# 2                   01º D.P. SE             DECAP
# 3                   01º D.P. SE             DECAP
# 4                   01º D.P. SE             DECAP
#
#   NOME_DEPARTAMENTO_CIRCUNSCRICAO NOME_MUNICIPIO NOME_MUNICIPIO_CIRCUNSCRICAO  \
# 0                           DECAP        S.PAULO                      S.PAULO
# 1                           DECAP        S.PAULO                      S.PAULO
# 2                           DECAP        S.PAULO                      S.PAULO
# 3                           DECAP        S.PAULO                      S.PAULO
# 4                           DECAP        S.PAULO                      S.PAULO
#
#           NOME_SECCIONAL NOME_SECCIONAL_CIRCUNSCRICAO NUMERO_LOGRADOURO  \
# 0  DEL.SEC.8º SAO MATEUS            DEL.SEC.1º CENTRO               NaN
# 1  DEL.SEC.8º SAO MATEUS            DEL.SEC.1º CENTRO               325
# 2       DEL.SEC.5º LESTE            DEL.SEC.1º CENTRO                10
# 3      DEL.SEC.1º CENTRO            DEL.SEC.1º CENTRO                 1
# 4      DEL.SEC.1º CENTRO            DEL.SEC.1º CENTRO               NaN
#
#    NUM_BO             RUBRICA
# 0  AC0851  Art. 213 - Estupro
# 1       4    Furto (art. 155)
# 2       7    Furto (art. 155)
# 3       8    Furto (art. 155)
# 4       8    Furto (art. 155)
#
# [5 rows x 23 columns]

# %%
# Salvar documentação em arquivo para referência
docs = """# PADRONIZAÇÃO DE COLUNAS - ANÁLISE E SOLUÇÃO

## Problema Identificado
As bases de dados (2022-2025) tinham inconsistências em nomes de colunas:
1. Mesma coluna com nomes diferentes
2. Algumas colunas presentes apenas em 2024-2025
3. Problema de acentuação em 2025 (sem circunflexo)

## Solução Implementada

### 1. Mapeamento de Colunas Equivalentes
| Função | 2022 | 2023 | 2024 | 2025 | Padrão Final |
|--------|------|------|------|------|-------------|
| Período | DESCR_PERIODO | DESC_PERIODO | DESC_PERIODO | DESC_PERIODO | DESC_PERIODO |
| Município | CIDADE | NOME_MUNICIPIO | NOME_MUNICIPIO | NOME_MUNICIPIO | NOME_MUNICIPIO |
| Circunscritivo | CIRCUNSCRIÇÃO | CIRCUNSCRIÇÃO | CIRCUNSCRIÇÃO | CIRCUNSCRICAO | CIRCUNSCRICAO |

### 2. Colunas Novas (2024-2025)
- BTL
- CIA
- CMD
- COD IBGE

### 3. Colunas Inconsistentes
**2022 Não Tem:** DATA_REGISTRO, DESCR_SUBTIPOLOCAL
**2023 Não Tem:** DATA_COMUNICACAO_BO, DESCR_TIPOLOCAL
**2024 Não Tem:** DESCR_TIPOLOCAL
**2025 Não Tem:** COD IBGE

## Datasets Finais Disponíveis

### df_total (Todas as colunas)
- 4.792.971 linhas
- 29 colunas
- ⚠️ Contém NaN onde colunas faltam

### df_total_completo (Apenas colunas completas) ✓✓✓ RECOMENDADO
- 4.792.971 linhas
- 23 colunas (presentes em todos 4 anos)
- Sem NaN (dados 100% completos)

## Colunas Completas (df_total_completo)
1. ANO_BO
2. ANO_ESTATISTICA
3. BAIRRO
4. DATA_OCORRENCIA_BO
5. DESCR_CONDUTA
6. DESC_PERIODO
7. HORA_OCORRENCIA_BO
8. LATITUDE
9. LOGRADOURO
10. LONGITUDE
11. MES_ESTATISTICA
12. NATUREZA_APURADA
13. NOME_DELEGACIA
14. NOME_DELEGACIA_CIRCUNSCRICAO
15. NOME_DEPARTAMENTO
16. NOME_DEPARTAMENTO_CIRCUNSCRICAO
17. NOME_MUNICIPIO
18. NOME_MUNICIPIO_CIRCUNSCRICAO
19. NOME_SECCIONAL
20. NOME_SECCIONAL_CIRCUNSCRICAO
21. NUMERO_LOGRADOURO
22. NUM_BO
23. RUBRICA
"""

with open("DOCUMENTACAO_COLUNAS.md", "w", encoding="utf-8") as f:
    f.write(docs)

print("✓ Documentação salva em: DOCUMENTACAO_COLUNAS.md")
# Out:
# ✓ Documentação salva em: DOCUMENTACAO_COLUNAS.md

# %%
df_total.head()
# Out:
#   NOME_DEPARTAMENTO         NOME_SECCIONAL            NOME_DELEGACIA  \
# 0             DECAP  DEL.SEC.8º SAO MATEUS        08ª DDM SAO MATEUS
# 1             DECAP  DEL.SEC.8º SAO MATEUS  54º D.P. CID. TIRADENTES
# 2             DECAP       DEL.SEC.5º LESTE    29º D.P. VILA PRUDENTE
# 3             DECAP      DEL.SEC.1º CENTRO               01º D.P. SE
# 4             DECAP      DEL.SEC.1º CENTRO          06º D.P. CAMBUCI
#
#   NOME_MUNICIPIO  NUM_BO  ANO_BO DATA_COMUNICACAO_BO DATA_OCORRENCIA_BO  \
# 0        S.PAULO  AC0851  2022.0          13/01/2022         01/09/2021
# 1        S.PAULO       4  2022.0          03/01/2022         31/12/2021
# 2        S.PAULO       7  2022.0          04/01/2022         30/12/2021
# 3        S.PAULO       8  2022.0          03/01/2022         03/01/2022
# 4        S.PAULO       8  2022.0          03/01/2022         03/01/2022
#
#   HORA_OCORRENCIA_BO     DESC_PERIODO  ...        DESCR_CONDUTA  \
# 0                NaN  EM HORA INCERTA  ...                  NaN
# 1           15:20:00              NaN  ...  INTERIOR DE VEICULO
# 2                NaN  EM HORA INCERTA  ...           TRANSEUNTE
# 3           16:00:00              NaN  ...  INTERIOR DE VEICULO
# 4           13:30:00              NaN  ...  INTERIOR DE VEICULO
#
#   NATUREZA_APURADA MES_ESTATISTICA ANO_ESTATISTICA DATA_REGISTRO  \
# 0          ESTUPRO             1.0          2022.0           NaN
# 1   FURTO - OUTROS             1.0          2022.0           NaN
# 2   FURTO - OUTROS             1.0          2022.0           NaN
# 3   FURTO - OUTROS             1.0          2022.0           NaN
# 4   FURTO - OUTROS             1.0          2022.0           NaN
#
#   DESCR_SUBTIPOLOCAL  CMD  BTL  CIA COD IBGE
# 0                NaN  NaN  NaN  NaN      NaN
# 1                NaN  NaN  NaN  NaN      NaN
# 2                NaN  NaN  NaN  NaN      NaN
# 3                NaN  NaN  NaN  NaN      NaN
# 4                NaN  NaN  NaN  NaN      NaN
#
# [5 rows x 31 columns]

# %%
df_total_completo.head()
# Out:
#    ANO_BO  ANO_ESTATISTICA                         BAIRRO DATA_OCORRENCIA_BO  \
# 0  2022.0           2022.0                             SE         01/09/2021
# 1  2022.0           2022.0  Centro Histórico de São Paulo         31/12/2021
# 2  2022.0           2022.0                             SE         30/12/2021
# 3  2022.0           2022.0                      Liberdade         03/01/2022
# 4  2022.0           2022.0                      LIBERDADE         03/01/2022
#
#          DESCR_CONDUTA     DESC_PERIODO HORA_OCORRENCIA_BO      LATITUDE  \
# 0                  NaN  EM HORA INCERTA                NaN             0
# 1  INTERIOR DE VEICULO              NaN           15:20:00   -23,5436238
# 2           TRANSEUNTE  EM HORA INCERTA                NaN  -23,54502538
# 3  INTERIOR DE VEICULO              NaN           16:00:00   -23,5535658
# 4  INTERIOR DE VEICULO              NaN           13:30:00  -23,55805038
#
#                                   LOGRADOURO     LONGITUDE  ...  \
# 0  VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS             0  ...
# 1                                25 de Março   -46,6325199  ...
# 2                        PARQUE DOM PEDRO II  -46,63109113  ...
# 3                 Viaduto Therezinha Zerbini   -46,6258725  ...
# 4                            RUA DO GLICERIO  -46,63022391  ...
#
#    NOME_DELEGACIA_CIRCUNSCRICAO NOME_DEPARTAMENTO  \
# 0                   01º D.P. SE             DECAP
# 1                   01º D.P. SE             DECAP
# 2                   01º D.P. SE             DECAP
# 3                   01º D.P. SE             DECAP
# 4                   01º D.P. SE             DECAP
#
#   NOME_DEPARTAMENTO_CIRCUNSCRICAO NOME_MUNICIPIO NOME_MUNICIPIO_CIRCUNSCRICAO  \
# 0                           DECAP        S.PAULO                      S.PAULO
# 1                           DECAP        S.PAULO                      S.PAULO
# 2                           DECAP        S.PAULO                      S.PAULO
# 3                           DECAP        S.PAULO                      S.PAULO
# 4                           DECAP        S.PAULO                      S.PAULO
#
#           NOME_SECCIONAL NOME_SECCIONAL_CIRCUNSCRICAO NUMERO_LOGRADOURO  \
# 0  DEL.SEC.8º SAO MATEUS            DEL.SEC.1º CENTRO               NaN
# 1  DEL.SEC.8º SAO MATEUS            DEL.SEC.1º CENTRO               325
# 2       DEL.SEC.5º LESTE            DEL.SEC.1º CENTRO                10
# 3      DEL.SEC.1º CENTRO            DEL.SEC.1º CENTRO                 1
# 4      DEL.SEC.1º CENTRO            DEL.SEC.1º CENTRO               NaN
#
#    NUM_BO             RUBRICA
# 0  AC0851  Art. 213 - Estupro
# 1       4    Furto (art. 155)
# 2       7    Furto (art. 155)
# 3       8    Furto (art. 155)
# 4       8    Furto (art. 155)
#
# [5 rows x 23 columns]

# %%
df_total_completo[df_total_completo["DESCR_CONDUTA"] == "Feminicídio-contra a mulher por razões da condição de sexo feminino."].shape[0]
# Out:
# 1636

# %%
df_total_completo[df_total_completo["DESCR_CONDUTA"] == "Feminicídio-contra a mulher por razões da condição de sexo feminino."]
# Out:
#          ANO_BO  ANO_ESTATISTICA              BAIRRO DATA_OCORRENCIA_BO  \
# 26207    2022.0           2022.0     PARQUE FERNANDA         22/01/2022
# 40911    2022.0           2022.0           BELVEDERE         12/01/2022
# 63082    2022.0           2022.0          AREA RURAL         12/01/2022
# 75414    2022.0           2022.0     PARQUE IMPERIAL         09/01/2022
# 75605    2022.0           2022.0        JD ESPERANÇA         24/01/2022
# ...         ...              ...                 ...                ...
# 4782161  2025.0           2025.0            PIMENTAS         25/12/2025
# 4783679  2025.0           2025.0     JARDIM MERCEDES         25/12/2025
# 4785493  2025.0           2025.0         VILA FÁTIMA         21/12/2025
# 4787006  2025.0           2025.0          VILA MENCK         06/12/2025
# 4789445  2025.0           2025.0  PARQUE SAO VICENTE         22/12/2025
#
#                                              DESCR_CONDUTA     DESC_PERIODO  \
# 26207    Feminicídio-contra a mulher por razões da cond...              NaN
# 40911    Feminicídio-contra a mulher por razões da cond...              NaN
# 63082    Feminicídio-contra a mulher por razões da cond...              NaN
# 75414    Feminicídio-contra a mulher por razões da cond...              NaN
# 75605    Feminicídio-contra a mulher por razões da cond...  EM HORA INCERTA
# ...                                                    ...              ...
# 4782161  Feminicídio-contra a mulher por razões da cond...              NaN
# 4783679  Feminicídio-contra a mulher por razões da cond...              NaN
# 4785493  Feminicídio-contra a mulher por razões da cond...              NaN
# 4787006  Feminicídio-contra a mulher por razões da cond...              NaN
# 4789445  Feminicídio-contra a mulher por razões da cond...              NaN
#
#         HORA_OCORRENCIA_BO      LATITUDE  \
# 26207             20:00:00             0
# 40911             20:10:00             0
# 63082             19:00:00             0
# 75414             21:00:00             0
# 75605                  NaN             0
# ...                    ...           ...
# 4782161         12:53:00.0   -23,4638742
# 4783679         16:00:55.0             0
# 4785493         08:16:00.0  -23,63088462
# 4787006         21:20:00.0  -23,48397345
# 4789445         11:21:00.0    -23,670958
#
#                                         LOGRADOURO     LONGITUDE  ...  \
# 26207    VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS             0  ...
# 40911    VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS             0  ...
# 63082    VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS             0  ...
# 75414    VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS             0  ...
# 75605    VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS             0  ...
# ...                                            ...           ...  ...
# 4782161                                RUA QUIMERA   -46,4098205  ...
# 4783679  VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS             0  ...
# 4785493                     RUA  RINIYASU SUGIMURA  -46,33558725  ...
# 4787006                  RUA CÉLIA CUBICI CAROBRES  -46,78063375  ...
# 4789445                    Avenida Papa João XXIII   -46,4696812  ...
#
#            NOME_DELEGACIA_CIRCUNSCRICAO       NOME_DEPARTAMENTO  \
# 26207            47º D.P. CAPAO REDONDO                   DECAP
# 40911                 DEL.POL.PENÁPOLIS  DEINTER 10 - ARAÇATUBA
# 63082                  01º D.P. GUARUJA      DEINTER 6 - SANTOS
# 75414                  02º D.P. BARUERI                 DEMACRO
# 75605                   DEL.POL.BARUERI                 DEMACRO
# ...                                 ...                     ...
# 4782161              04º D.P. GUARULHOS                 DEMACRO
# 4783679     01º D.P. FERRAZ VASCONCELOS                 DEMACRO
# 4785493                 01º D.P. SUZANO                 DEMACRO
# 4787006                 07º D.P. OSASCO                   DECAP
# 4789445  01º DP MAUA-DR.ALFREDO GARBINO                 DEMACRO
#
#         NOME_DEPARTAMENTO_CIRCUNSCRICAO         NOME_MUNICIPIO  \
# 26207                             DECAP                S.PAULO
# 40911            DEINTER 10 - ARAÇATUBA              PENAPOLIS
# 63082                DEINTER 6 - SANTOS                GUARUJA
# 75414                           DEMACRO                BARUERI
# 75605                           DEMACRO                BARUERI
# ...                                 ...                    ...
# 4782161                         DEMACRO              GUARULHOS
# 4783679                         DEMACRO  FERRAZ DE VASCONCELOS
# 4785493                         DEMACRO                 SUZANO
# 4787006                         DEMACRO                 OSASCO
# 4789445                         DEMACRO                   MAUA
#
#         NOME_MUNICIPIO_CIRCUNSCRICAO           NOME_SECCIONAL  \
# 26207                        S.PAULO   DEL.SEC.6º SANTO AMARO
# 40911                      PENAPOLIS        DEL.SEC.ARACATUBA
# 63082                        GUARUJA           DEL.SEC.SANTOS
# 75414                        BARUERI      DEL.SEC.CARAPICUIBA
# 75605                        BARUERI      DEL.SEC.CARAPICUIBA
# ...                              ...                      ...
# 4782161                    GUARULHOS        DEL.SEC.GUARULHOS
# 4783679        FERRAZ DE VASCONCELOS  DEL.SEC.MOGI DAS CRUZES
# 4785493                       SUZANO  DEL.SEC.MOGI DAS CRUZES
# 4787006                       OSASCO         DEL.SEC.3º OESTE
# 4789445                         MAUA      DEL.SEC.SANTO ANDRÉ
#
#         NOME_SECCIONAL_CIRCUNSCRICAO NUMERO_LOGRADOURO  NUM_BO  \
# 26207         DEL.SEC.6º SANTO AMARO               NaN  AE2379
# 40911              DEL.SEC.ARACATUBA               NaN  AC0317
# 63082                 DEL.SEC.SANTOS               NaN  AC4630
# 75414            DEL.SEC.CARAPICUIBA               NaN  AB3503
# 75605            DEL.SEC.CARAPICUIBA               NaN  AF1638
# ...                              ...               ...     ...
# 4782161            DEL.SEC.GUARULHOS             152.0  SV3297
# 4783679      DEL.SEC.MOGI DAS CRUZES               NaN  SW3123
# 4785493      DEL.SEC.MOGI DAS CRUZES              61.0  SQ5281
# 4787006               DEL.SEC.OSASCO             131.0  RY9712
# 4789445          DEL.SEC.SANTO ANDRÉ             100.0  SR8518
#
#                       RUBRICA
# 26207    Homicídio (art. 121)
# 40911    Homicídio (art. 121)
# 63082    Homicídio (art. 121)
# 75414    Homicídio (art. 121)
# 75605    Homicídio (art. 121)
# ...                       ...
# 4782161  Homicídio (art. 121)
# 4783679  Homicídio (art. 121)
# 4785493  Homicídio (art. 121)
# 4787006  Homicídio (art. 121)
# 4789445  Homicídio (art. 121)
#
# [1636 rows x 23 columns]
